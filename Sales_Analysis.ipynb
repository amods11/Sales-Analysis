# %% [markdown]
# #### Importing Necessary Libraries

# %%
import pandas as pd
import os

# %%
df = pd.read_csv("datasets/Sales_Data/Sales_April_2019.csv")
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#          Order Date                      Purchase Address
# 0    04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04-07-2019 22:30     682 Chestnut St, Boston, MA 02215
# 2  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 4    04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# #### Merge the 12 months of sales data into a single CSV file

# %%
path = "E:/jupyter/datasets/Sales_Data"
files = [file for file in os.listdir(path)]

all_months_data = pd.DataFrame()

for file in files:
    df = pd.read_csv("E:/jupyter/datasets/Sales_Data/" + file)
    all_months_data = pd.concat([all_months_data, df])
    
all_months_data.head()


all_months_data.to_csv("all_data.csv", index = False)

# %% [markdown]
# ##### Read in Updated Dataframe

# %%
all_data = pd.read_csv("all_data.csv")
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#          Order Date                      Purchase Address
# 0    04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04-07-2019 22:30     682 Chestnut St, Boston, MA 02215
# 2  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 4    04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ##### Drop rows of NaN

# %%
nan_df = all_data[all_data.isna().any(axis=1)]
nan_df.head()
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 355       NaN     NaN              NaN        NaN        NaN              NaN
# 734       NaN     NaN              NaN        NaN        NaN              NaN
# 1432      NaN     NaN              NaN        NaN        NaN              NaN
# 1552      NaN     NaN              NaN        NaN        NaN              NaN
# 1570      NaN     NaN              NaN        NaN        NaN              NaN

# %%
all_data = all_data.dropna(how = "all")

# %% [markdown]
# ##### Find "Or" and delete it

# %%
# temp_df = all_data.loc[all_data["Order Date"].str[0:2] == "Or"]
# temp_df.head()
all_data = all_data.loc[all_data["Order Date"].str[0:2] != "Or"]

# %% [markdown]
# ##### Convert columns to the correct type

# %%
all_data["Quantity Ordered"] = pd.to_numeric(all_data["Quantity Ordered"]) # Make int
all_data["Price Each"] = pd.to_numeric(all_data["Price Each"]) # Make float

# %% [markdown]
# ### Augmenting Data with additional Columns

# %% [markdown]
# #### Adding Month Column

# %%
all_data["Month"] = all_data["Order Date"].str[0:2]
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#          Order Date                      Purchase Address Month
# 0    04/19/19 08:46          917 1st St, Dallas, TX 75001    04
# 1  04-07-2019 22:30     682 Chestnut St, Boston, MA 02215    04
# 2  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 3  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 4    04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04

# %%
all_data.tail()
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 186844   259353  AAA Batteries (4-pack)                 3        2.99
# 186845   259354                  iPhone                 1      700.00
# 186846   259355                  iPhone                 1      700.00
# 186847   259356  34in Ultrawide Monitor                 1      379.99
# 186848   259357    USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address Month
# 186844  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001    09
# 186845  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016    09
# 186846  09/23/19 07:39     220 12th St, San Francisco, CA 94016    09
# 186847  09/19/19 17:30   511 Forest St, San Francisco, CA 94016    09
# 186848  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016    09

# %%
# Convert the values of month column into int values
all_data["Month"] = all_data["Month"].astype("int32")
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#          Order Date                      Purchase Address  Month
# 0    04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 1  04-07-2019 22:30     682 Chestnut St, Boston, MA 02215      4
# 2  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 3  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4    04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4

# %% [markdown]
# #### Adding a sales column

# %%
all_data["Sales"] = all_data["Quantity Ordered"] * all_data["Price Each"]
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#          Order Date                      Purchase Address  Month   Sales
# 0    04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 1  04-07-2019 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 2  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4    04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99

# %% [markdown]
# #### Adding a City Column

# %%
def get_city(address):
    return address.split(",")[1]

def get_state(address):
    return address.split(",")[2].split(" ")[1]


all_data["City"] = all_data["Purchase Address"].apply(lambda x: f"{get_city(x)} ({get_state(x)})")
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#          Order Date                      Purchase Address  Month   Sales  \
# 0    04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 1  04-07-2019 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 2  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4    04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99
#
#                 City
# 0        Dallas (TX)
# 1        Boston (MA)
# 2   Los Angeles (CA)
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Question 1: What was the best month for sales? How much was earned that month?

# %%
results = all_data.groupby("Month").sum()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (6, 4), dpi = 120)

months = range(1, 13)
results = all_data.groupby("Month").sum()

plt.bar(months, results["Sales"])

plt.xticks(months)
plt.xlabel("Month Number", fontdict = {"fontsize": 12, "fontname": "Times New Roman"})
plt.ylabel("Sales in USD ($)", fontdict = {"fontsize": 12, "fontname": "Times New Roman"})

plt.show()

# %% [markdown]
# ### As we can see that the month of December had the best sales overall in the entire year with over $4,000,000 worth of sales recorded.

# %% [markdown]
# ### Question 2: What city had the highest number of sales?

# %%
results = all_data.groupby("City").sum()
results
# Out:
#                      Quantity Ordered    Price Each   Month         Sales
# City
#  Atlanta (GA)                   16602  2.779908e+06  104794  2.795499e+06
#  Austin (TX)                    11153  1.809874e+06   69829  1.819582e+06
#  Boston (MA)                    22528  3.637410e+06  141112  3.661642e+06
#  Dallas (TX)                    16730  2.752628e+06  104620  2.767975e+06
#  Los Angeles (CA)               33289  5.421435e+06  208325  5.452571e+06
#  New York City (NY)             27932  4.635371e+06  175741  4.664317e+06
#  Portland (ME)                   2750  4.471893e+05   17144  4.497583e+05
#  Portland (OR)                  11303  1.860558e+06   70621  1.870732e+06
#  San Francisco (CA)             50239  8.211462e+06  315520  8.262204e+06
#  Seattle (WA)                   16553  2.733296e+06  104941  2.747755e+06

# %%
plt.figure(figsize = (6, 4), dpi = 120)

cities = [city for city, df in all_data.groupby("City")]


plt.bar(cities, results["Sales"])

plt.xticks(cities, rotation = "vertical")
plt.xlabel("City Name", fontdict = {"fontsize": 12, "fontname": "Times New Roman"})
plt.ylabel("Sales in USD ($)", fontdict = {"fontsize": 12, "fontname": "Times New Roman"})

plt.show()

# %% [markdown]
# ### The city of San Francisco had the highest number of sales.

# %% [markdown]
# ### Question 3: What time should we display advertisements to maximise the likelihood of customer's buying product?

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#          Order Date                      Purchase Address  Month   Sales  \
# 0    04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 1  04-07-2019 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 2  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3  04-12-2019 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4    04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99
#
#                 City
# 0        Dallas (TX)
# 1        Boston (MA)
# 2   Los Angeles (CA)
# ...

# %%
all_data["Order Date"] = pd.to_datetime(all_data["Order Date"])

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#                 City
# 0        Dallas (TX)
# 1        Boston (MA)
# 2   Los Angeles (CA)
# ...

# %%
all_data["Hour"] = all_data["Order Date"].dt.hour
all_data["Minute"] = all_data["Order Date"].dt.minute
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#                 City  Hour  Minute
# 0        Dallas (TX)     8      46
# ...

# %%
plt.figure(figsize = (6, 4), dpi = 120)


hours = [hour for hour, df in all_data.groupby("Hour")]

plt.plot(hours, all_data.groupby("Hour").count())
plt.xticks(hours)
plt.xlabel("Hour", fontdict = {"fontsize": 12, "fontname": "Times New Roman"})
plt.ylabel("Number of Orders", fontdict = {"fontsize": 12, "fontname": "Times New Roman"})

plt.grid()
plt.show()

# %% [markdown]
# ### This chart shows us that there are two peaks of sales during the day. So, to answer the question the advertisements should be displayed between 11 AM and 12 Noon and between 6 PM and 7 PM in the evening.

# %% [markdown]
# ### Question 4: What products are most often sold together?

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#                 City  Hour  Minute
# 0        Dallas (TX)     8      46
# ...

# %%
df = all_data[all_data["Order ID"].duplicated(keep = False)]
df.head(20)
# Out:
#     Order ID                     Product  Quantity Ordered  Price Each  \
# 2     176560                Google Phone                 1      600.00
# 3     176560            Wired Headphones                 1       11.99
# 17    176574                Google Phone                 1      600.00
# 18    176574        USB-C Charging Cable                 1       11.95
# 29    176585  Bose SoundSport Headphones                 1       99.99
# 30    176585  Bose SoundSport Headphones                 1       99.99
# 31    176586      AAA Batteries (4-pack)                 2        2.99
# 32    176586                Google Phone                 1      600.00
# 118   176672    Lightning Charging Cable                 1       14.95
# 119   176672        USB-C Charging Cable                 1       11.95
# 128   176681    Apple Airpods Headphones                 1      150.00
# 129   176681             ThinkPad Laptop                 1      999.99
# ...

# %%
df["Grouped"] = df.groupby("Order ID")["Product"].transform(lambda x: ",".join(x))
df.head()
# Out:
# E:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 2    176560                Google Phone                 1      600.00
# 3    176560            Wired Headphones                 1       11.99
# 17   176574                Google Phone                 1      600.00
# 18   176574        USB-C Charging Cable                 1       11.95
# 29   176585  Bose SoundSport Headphones                 1       99.99
#
#             Order Date                      Purchase Address  Month   Sales  \
# 2  2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# ...

# %%
# Dropping duplicated occurrences of the same order
df = df[["Order ID", "Grouped"]].drop_duplicates()
df.head(20)
# Out:
#     Order ID                                            Grouped
# 2     176560                      Google Phone,Wired Headphones
# 17    176574                  Google Phone,USB-C Charging Cable
# 29    176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 31    176586                AAA Batteries (4-pack),Google Phone
# 118   176672      Lightning Charging Cable,USB-C Charging Cable
# 128   176681           Apple Airpods Headphones,ThinkPad Laptop
# 137   176689  Bose SoundSport Headphones,AAA Batteries (4-pack)
# 188   176739                34in Ultrawide Monitor,Google Phone
# 224   176774      Lightning Charging Cable,USB-C Charging Cable
# 232   176781                    iPhone,Lightning Charging Cable
# 249   176797  Google Phone,Bose SoundSport Headphones,Wired ...
# 259   176805                  Google Phone,USB-C Charging Cable
# 263   176808                      Google Phone,Wired Headphones
# 269   176813                      Google Phone,Wired Headphones
# ...

# %%
from itertools import combinations
from collections import Counter

count = Counter()

for row in df["Grouped"]:
    row_list = row.split(",")
    count.update(Counter(combinations(row_list, 2)))
    
#print(count)

for key, value in count.most_common(10):
    print (key, value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
# ### The products which are most often sold together are Iphone and Lightning Charging Cable.

# %% [markdown]
# ### Question 5: What product sold the most? Why do you think it sold the most?

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#                 City  Hour  Minute
# 0        Dallas (TX)     8      46
# ...

# %%
plt.figure(figsize = (6, 4), dpi = 120)

product_group = all_data.groupby("Product")
quantity_ordered = product_group.sum()["Quantity Ordered"]

products = [product for product, df in product_group]

plt.bar(products, quantity_ordered)

plt.ylabel("Quantity Ordered", fontdict = {"fontsize": 12, "fontname": "Times New Roman"})
plt.xlabel("Product Name", fontdict = {"fontsize": 12, "fontname": "Times New Roman"})
plt.xticks(products, rotation = "vertical")

plt.show()

# %%
prices = all_data.groupby("Product").mean()["Price Each"]
prices
# Out:
# Product
# 20in Monitor                   109.99
# 27in 4K Gaming Monitor         389.99
# 27in FHD Monitor               149.99
# 34in Ultrawide Monitor         379.99
# AA Batteries (4-pack)            3.84
# AAA Batteries (4-pack)           2.99
# Apple Airpods Headphones       150.00
# Bose SoundSport Headphones      99.99
# Flatscreen TV                  300.00
# Google Phone                   600.00
# LG Dryer                       600.00
# LG Washing Machine             600.00
# Lightning Charging Cable        14.95
# Macbook Pro Laptop            1700.00
# ThinkPad Laptop                999.99
# USB-C Charging Cable            11.95
# Vareebadd Phone                400.00
# Wired Headphones                11.99
# iPhone                         700.00
# Name: Price Each, dtype: float64

# %%
fig, ax1 = plt.subplots(figsize = (6, 4), dpi = 120)

ax2 = ax1.twinx()
ax1.bar(products, quantity_ordered, color = "g")
ax2.plot(products, prices, 'b-')

ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity Ordered', color= "g")
ax2.set_ylabel('Price ($)', color='b')
ax1.set_xticklabels(products, rotation = "vertical", size = 8)

plt.show()

# %% [markdown]
# ### A 4-pack of AAA Batteries sold the most followed by a 4-pack of AA batteries. The reason why they sold the most was because it's price was cheap. On the other hand, the expensive products like the LG Dryer and the LG Washing Machine were sold less because it was comparatively expensive.
